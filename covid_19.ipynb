# %%
# IMPORT THE LIBERARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import the dataset
dataset = pd.read_csv('/content/covid19_Confirmed_dataset.csv')
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %%
print(dataset.columns)
# Out:
# Index(['Province/State', 'Country/Region', '1/22/20', '1/23/20', '1/24/20',
#        '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        ...
#        '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20',
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20'],
#       dtype='object', length=102)

# %%
print(dataset.columns.tolist())
# Out:
# ['Province/State', 'Country/Region', '1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20', '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20', '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20', '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20', '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20', '4/9/20', '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20', '4/15/20', '4/16/20', '4/17/20', '4/18/20', '4/19/20', '4/20/20'
# ...

# %%
df = dataset.drop(columns=[col for col in ['Lat','Long'] if col in dataset.columns])

# %%
dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
#aggregrate the rows by the country
corona_dataset_aggregrate = dataset.groupby("Country/Region").sum()

# %%
corona_dataset_aggregrate.head()
# Out:
#                Province/State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Afghanistan                 0        0        0        0        0        0
# Albania                     0        0        0        0        0        0
# Algeria                     0        0        0        0        0        0
# Andorra                     0        0        0        0        0        0
# Angola                      0        0        0        0        0        0
#
#                 1/27/20  1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...     1092     1176
# Albania               0        0        0        0  ...      609      634
# Algeria               0        0        0        0  ...     2811     2910
# Andorra               0        0        0        0  ...      717      723
# ...

# %%
corona_dataset_aggregrate.shape
# Out:
# (187, 101)

# %%
df = dataset.drop(['Province/State'], axis=1)

# %%
df.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

def plot_countries(countries, df):
    plt.figure(figsize=(12,6))

    for country_name in countries:
        # Select rows for the country
        country_df = df.loc[country_name]

        # If only one row (Series)
        if isinstance(country_df, pd.Series):
            country_df = pd.to_numeric(country_df, errors='coerce')
            country_df.dropna().plot(label=country_name)

        # If multiple rows (DataFrame with provinces)
        else:
            country_df = country_df.drop(['Province/State'], axis=1, errors='ignore')
            country_df = country_df.apply(pd.to_numeric, errors='coerce')
            country_df = country_df.sum(axis=0)
            country_df.plot(label=country_name)

    plt.title("COVID Trend Comparison")
    plt.xlabel("Date")
    plt.ylabel("Cases")
    plt.legend()
    plt.show()

# %%
plot_countries(["China", "India", "Spain"], corona_dataset_aggregrate)

# %%
#calcualate a good measures
# Select China row(s)
china_df = corona_dataset_aggregrate.loc["China"]

# Drop non-numeric columns and convert the rest to numbers
china_df_numeric = china_df.apply(pd.to_numeric, errors='coerce')

# Drop NaNs just in case
china_df_numeric = china_df_numeric.dropna()

# Plot
china_df_numeric.plot(title="COVID Trend in China", figsize=(10,5))
plt.ylabel("Cases")
plt.xlabel("Date")
plt.show()

# %%
#calculate the first derivate of the curve
# Select China row(s)
china_df = corona_dataset_aggregrate.loc["China"]

# If multiple provinces, sum first
if isinstance(china_df, pd.DataFrame):
    china_df = china_df.drop(['Province/State'], axis=1, errors='ignore')
    china_df = china_df.apply(pd.to_numeric, errors='coerce')
    china_df = china_df.sum(axis=0)
else:
    china_df = china_df.apply(pd.to_numeric, errors='coerce')

# Calculate daily new cases
china_daily = china_df.diff()

# Plot daily new cases
china_daily.plot(title="Daily New COVID Cases in China", figsize=(10,5))
plt.ylabel("Daily Cases")
plt.xlabel("Date")
plt.show()

# %%
countries = list(corona_dataset_aggregrate.index)
max_infection_rates = []

for c in countries:
    country_df = corona_dataset_aggregrate.loc[c]

    # If multiple provinces, sum them
    if isinstance(country_df, pd.DataFrame):
        country_df = country_df.drop(['Province/State'], axis=1, errors='ignore')
        country_df = country_df.apply(pd.to_numeric, errors='coerce')
        country_df = country_df.sum(axis=0)
    else:
        country_df = country_df.apply(pd.to_numeric, errors='coerce')

    # Daily new cases
    daily_cases = country_df.diff()
    max_infection_rates.append(daily_cases.max())

# Add new column
corona_dataset_aggregrate['max_infection_rate'] = max_infection_rates

# Check results
corona_dataset_aggregrate
# Out:
#                    Province/State  1/22/20  1/23/20  1/24/20  1/25/20  \
# Country/Region
# Afghanistan                     0        0        0        0        0
# Albania                         0        0        0        0        0
# Algeria                         0        0        0        0        0
# Andorra                         0        0        0        0        0
# Angola                          0        0        0        0        0
# ...                           ...      ...      ...      ...      ...
# West Bank and Gaza              0        0        0        0        0
# Western Sahara                  0        0        0        0        0
# Yemen                           0        0        0        0        0
# Zambia                          0        0        0        0        0
# Zimbabwe                        0        0        0        0        0
#
#                     1/26/20  1/27/20  1/28/20  1/29/20  1/30/20  ...  4/22/20  \
# ...

# %%
#create a new dataframe
corona_data = pd.DataFrame(corona_dataset_aggregrate["max_infection_rate"])
corona_data
# Out:
#                     max_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %%
# importing the dataset 2
happiness_report  = pd.read_csv('/content/worldwide_happiness_report.csv')
happiness_report
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
#drop the useless columns
useless_cols= ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happiness_report.drop(useless_cols, axis=1, inplace=True, errors='ignore')

# %%
# Get columns that exist in the DataFrame
cols_to_drop = [col for col in useless_cols if col in happiness_report.columns]

# Drop only existing columns
happiness_report.drop(cols_to_drop, axis=1, inplace=True)

# %%
print(happiness_report.columns.tolist())
# Out:
# ['Country or region', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices']

# %%
happiness_report.drop(columns=[col for col in useless_cols if col in happiness_report.columns], inplace=True)

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.set_index("Country or region", inplace=True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
#join the dataset
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report, how="inner")
data
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %%
data
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
# ...                         ...             ...             ...
# Venezuela                  29.0           0.960           1.427
# Vietnam                    19.0           0.741           1.346
# Yemen                       5.0           0.287           1.163
# Zambia                      9.0           0.578           1.058
# Zimbabwe                    8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %%
# visulaization
print(data.columns.tolist())
# Out:
# ['max_infection_rate', 'GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices']

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Make sure to use correct column names
X = data["GDP per capita"]
Y = data["max_infection_rate"]

# Log-transform Y
sns.scatterplot(x=X, y=np.log(Y + 1))  # +1 avoids log(0) issues

plt.title("GDP per Capita vs Max COVID Infection Rate (Log Y)")
plt.xlabel("GDP per Capita")
plt.ylabel("Log of Max Infection Rate")
plt.show()

# %%
sns.regplot(x=X, y=np.log(Y + 1))


#
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Make sure to use correct column names
X = data["Social support"]
Y = data["max_infection_rate"]

# Log-transform Y
sns.scatterplot(x=X, y=np.log(Y + 1))  # +1 avoids log(0) issues

plt.title("GDP per Capita vs Max COVID Infection Rate (Log Y)")
plt.xlabel("GDP per Capita")
plt.ylabel("Log of Max Infection Rate")
plt.show()

# %%
sns.regplot(x=X, y=np.log(Y + 1))
# Out:
# <Axes: xlabel='Social support', ylabel='max_infection_rate'>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Make sure to use correct column names
X = data["Healthy life expectancy"]
Y = data["max_infection_rate"]

# Log-transform Y
sns.scatterplot(x=X, y=np.log(Y + 1))  # +1 avoids log(0) issues

plt.title("GDP per Capita vs Max COVID Infection Rate (Log Y)")
plt.xlabel("GDP per Capita")
plt.ylabel("Log of Max Infection Rate")
plt.show()

# %%
sns.regplot(x=X, y=np.log(Y + 1))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Make sure to use correct column names
X = data["Freedom to make life choices"]
Y = data["max_infection_rate"]

# Log-transform Y
sns.scatterplot(x=X, y=np.log(Y + 1))  # +1 avoids log(0) issues

plt.title("GDP per Capita vs Max COVID Infection Rate (Log Y)")
plt.xlabel("GDP per Capita")
plt.ylabel("Log of Max Infection Rate")
plt.show()

# %%
sns.regplot(x=X, y=np.log(Y + 1))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='max_infection_rate'>
